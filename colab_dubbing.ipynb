# %% [markdown]
# # 🎙️ Trợ lý Lồng Tiếng YouTube AI trên Google Colab
# Tận dụng hạ tầng GPU miễn phí (NVIDIA T4 / A100) của Google Colab để chạy tách giọng Demucs, bóc băng Whisper và lồng tiếng OmniVoice/EdgeTTS siêu nhanh.
#
# > ⚠️ **Lưu ý:** Hãy nhớ bật GPU trước khi chạy: Vào menu **Runtime** (Thời gian chạy) ➔ **Change runtime type** (Thay đổi loại phần cứng) ➔ Chọn **T4 GPU** ➔ Nhấn **Save**.

# %%
# 1. Kiểm tra thông số GPU
# !nvidia-smi

# %%
# 2. Cài đặt FFmpeg đầy đủ (hỗ trợ libass để đốt phụ đề)
# !apt-get update -qq && apt-get install -y ffmpeg

# %%
# 3. Tải mã nguồn dự án vào Colab
# --- CÁCH A: Clone từ GitHub (Khuyên dùng - thay link repo của bạn vào bên dưới):
# !git clone https://github.com/<tai-khoan-cua-ban>/<ten-repo>.git
# %cd <ten-repo>

# --- CÁCH B: Nếu bạn tải thư mục dự án lên Google Drive:
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/you_tobe_dubbing_app_clone

# %%
# 4. Cài đặt các thư viện Python cần thiết
# !pip install -q -r requirements.txt

# %%
# 5. Khởi chạy Web UI (sẽ sinh link https://xxx.gradio.live để mở app trên trình duyệt)
# !python app_ui.py --share
